# %% [markdown]
# #  INTELECT: THE POWER OF KNOWIING
# ## Mashine Lerning/Neurons
# ### AI >ML>Model>Neural Networks>[Neuron]
# <hr>
# !!! WE ARE HERE
#
# [ANI]>[AGI]>[ASI]
# * Artificial Neuron Inteligence (Insects)
# * Artificial Glogal Inteligente (Human)
# * Artificial Super inteligence  (Super)
#
# <img src="img1.png" style="width:200px;height 400px"/>
# <img src="img2.png" style="width:200px;height 400px"/>
# <img src="img3.png" style="width:200px;height 400px"/>
# <hr>
#
# ##  The "Perceptron"
#
#         A Perceptron is an artificial Neuron
#         It's the simplest BUILDING BLOCK of a NN
# * THE MODEL of a perceptron according to Frank Rosenblatt(1928 -1971), who was an American psychologist
#
# <img src="img4.png" style="width:400px;height 400px"/>
# <img src="img5.png" style="width:400px;height 400px"/>
#
# * Here is the matematical approximation of real perceptron IT HAS:
#   * inputs: X
#   * output: Y
#   * weights: Wn
#   * bias: B
#   * activation function: af
#
#
#   <img src="img6.png" style="width:600px;height 600px"/>
#
# * The activation function can differ
#
#   <img src="img7.png" style="width:600px;height 600px"/>
# <hr>
#
# * <h4>To understand better how a perceptron works le's imagene the real examples:</h4>
#
# <img src="img8.png" style="width:525px;height 600px"/>
# <img src="img9.png" style="width:600px;height 600px"/>
# <hr>
#
# # Complexity
# * How complex problems can a SINGLE NEURON solve?
#
# <img src="img10.png" style="width:600px;height 600px"/>
# Spider:200k Neurons
# <hr>
# <img src="img11.png" style="width:600px;height 600px"/>
# Honey Bee: 1M Neurons
# <hr>
# <img src="img12.png" style="width:600px;height 600px"/>
# Dog: 400+M neurons
# <hr>
# <img src="img13.png" style="width:600px;height 600px"/>
# Human: 80+B neurons (~10000 B synapses)
# <hr>
# <img src="img14.png" style="width:600px;height 600px"/>
# Super Intelligence: 500+B parameters
# <hr>

# %% [markdown]
# https://brilliant.org/courses/probability-fundamentals/introduction-75/uniform-probabilities-2/1/
#
#
# ### State of The Art (for those who lost the track)
#
# https://www.youtube.com/watch?v=BwcVm0YRvuo
# https://www.youtube.com/watch?v=aUSSfo5nCdM&t=152s
# https://www.youtube.com/watch?v=PqbB07n_uQ4
#
# ### ML
# https://www.youtube.com/watch?v=HcqpanDadyQ
# https://www.youtube.com/watch?v=3ZZOd4_m1Xc
# https://www.youtube.com/watch?v=qu_WEHvGXWk
#
# ### Neural Networks
# https://www.youtube.com/watch?v=bfmFfD2RIcg
# (ru) https://www.youtube.com/watch?v=GT6imQDxqko
# (ru) https://www.youtube.com/watch?v=0sP5kFXbHrM
#
# ### Perceptrons
# https://www.youtube.com/watch?v=-KLnurhX-Pg (untill the python part)
# https://www.youtube.com/watch?v=i3crGbdElSw
